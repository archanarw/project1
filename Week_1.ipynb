# %% [raw]
# INTRODUCTION:
# The dataset chosen is description of characters in Marvel and DC comics.
# The data comes from Marvel Wikia and DC Wikia. Characters were scraped on August 24. Appearance counts were scraped on September 2. The month and year of the first issue each character appeared in was pulled on October 6.
# The data is split into two files, for DC and Marvel, respectively: dc-wikia-data.csv and marvel-wikia-data.csv. Each file has the following variables:
# *The unique identifier for that characters page within the wikia name.
# *The name of the character urlslug.
# *The unique url within the wikia that takes you to the character ID.
# *The identity status of the character (Secret Identity, Public identity.
# *If the character is Good, Bad or Neutral.
# *Eye color of the character.
# *Hair color of the character.
# *Sex of the character (e.g. Male, Female, etc.).
# *GSM | If the character is a gender or sexual minority (e.g. Homosexual characters, bisexual characters).
# *If the character is alive or deceased.
# *The number of appareances of the character in comic books.
# *The month and year of the character's first appearance in a comic book, if available.
# *The year of the character's first appearance in a comic book, if available.

# %%
import pandas as pd
import matplotlib.pyplot as plt
marvel=pd.read_csv("marvel.csv")
dc=pd.read_csv("dc.csv")

# %%
marvel.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# ...

# %%
dc.head()
# Out:
#    page_id                         name                              urlslug  \
# 0     1422         Batman (Bruce Wayne)         \/wiki\/Batman_(Bruce_Wayne)
# 1    23387        Superman (Clark Kent)        \/wiki\/Superman_(Clark_Kent)
# 2     1458   Green Lantern (Hal Jordan)   \/wiki\/Green_Lantern_(Hal_Jordan)
# 3     1659     James Gordon (New Earth)     \/wiki\/James_Gordon_(New_Earth)
# 4     1576  Richard Grayson (New Earth)  \/wiki\/Richard_Grayson_(New_Earth)
#
#                 ID            ALIGN         EYE        HAIR              SEX  \
# 0  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 1  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 2  Secret Identity  Good Characters  Brown Eyes  Brown Hair  Male Characters
# 3  Public Identity  Good Characters  Brown Eyes  White Hair  Male Characters
# 4  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
#
# ...

# %% [raw]
# 1. Maximum number of appearances of a female character in marvel v/s DC:

# %%
marvel.loc[marvel['SEX']=='Female Characters'].sort_values(by ='APPEARANCES', ascending=False)
# Out:
#        page_id                                           name  \
# 11        1863                        Susan Storm (Earth-616)
# 13        2614                       Ororo Munroe (Earth-616)
# 17        1978                   Mary Jane Watson (Earth-616)
# 24        2512                     Wanda Maximoff (Earth-616)
# 26        1976                     Janet van Dyne (Earth-616)
# 27       65219                          Jean Grey (Earth-616)
# 28        6545                   Natalia Romanova (Earth-616)
# 31        8650                         May Reilly (Earth-616)
# 32        2527                    Katherine Pryde (Earth-616)
# 33        1970                      Carol Danvers (Earth-616)
# 34       37690                   Jennifer Walters (Earth-616)
# 35        3765                         Emma Frost (Earth-616)
# 38        1677                 Rogue (Anna Marie) (Earth-616)
# 45        2307                 Elizabeth Braddock (Earth-616)
# ...

# %%
dc.loc[dc['SEX']=='Female Characters'].sort_values(by ='APPEARANCES', ascending=False)
# Out:
#       page_id                              name  \
# 5        1448       Wonder Woman (Diana Prince)
# 8       71760    Dinah Laurel Lance (New Earth)
# 10     403631                        GenderTest
# 12       1905        Barbara Gordon (New Earth)
# 14      23383             Lois Lane (New Earth)
# 21       1580            Kara Zor-L (Earth-Two)
# 34       1577        Zatanna Zatara (New Earth)
# 38       1607   Cassandra Sandsmark (New Earth)
# 41       1864           Rachel Roth (New Earth)
# 42      37696     Helena Bertinelli (New Earth)
# 58       1723      Beatriz da Costa (New Earth)
# 60       1625          Carol Ferris (New Earth)
# 63      39947  Jennifer-Lynn Hayden (New Earth)
# 65       8856         Renee Montoya (New Earth)
# 67       1696     Courtney Whitmore (New Earth)
# 68       1894       Kendra Saunders (New Earth)
# 71       1870           Kara Zor-El (New Earth)
# 74       1464          Pamela Isley (New Earth)
# ...

# %% [raw]
# Therefore, in marvel the most appearing female character is Susan Strom, appearing 1713 times whereas in DC, the most appearing female character is GenderTest, appearing 1028 times.

# %% [raw]
# 2. The youngest characters in both Marvel and DC:

# %%
marvel.sort_values(by ='Year', ascending=False)#To find the latest year during which the character was created.
# Out:
#        page_id                                               name  \
# 16175   611134                           Mole Monster (Earth-616)
# 15025   579240                         Natalie Turner (Earth-616)
# 3638    564728                     Gorr (God Butcher) (Earth-616)
# 15038   670426             Zubar (Legion Personality) (Earth-616)
# 15037   637730                         Zachary Taylor (Earth-616)
# 15036   670500    Wormwhole Wodo (Legion Personality) (Earth-616)
# 15035   637723                 William Henry Harrison (Earth-616)
# 15034   687320                     War (11th Century) (Earth-616)
# 15033   680346                   Thing Under the Sand (Earth-616)
# 15032   670487         Skinsmith (Legion Personality) (Earth-616)
# 15031   632001                                 Sacino (Earth-616)
# 15030   606381                         Robert Michaud (Earth-616)
# 15029   670470       Pukatus Jr. (Legion Personality) (Earth-616)
# ...

# %%
m1=marvel.loc[marvel['Year']==2013]   #We choose the latest year and save the DataFrame for that year in a separate variable, so that finding the month from "FIRST APPEARANCE" column is easier.
m1
# Out:
#        page_id                                               name  \
# 707     563846                               Eva Bell (Earth-616)
# 764     563845                       Christopher Muse (Earth-616)
# 952     571723                         Benjamin Deeds (Earth-616)
# 971     581852                           Fabio Medina (Earth-616)
# 1234    581268                            Isabel Kane (Earth-616)
# 1364    607100                          Emily Preston (Earth-616)
# 1365    563804                        Iara Dos Santos (Earth-616)
# 1366    591658                           Kevin Connor (Earth-616)
# 1453    627377                     Anna Maria Marconi (Earth-616)
# 1563    573762                             H.E.L.E.N. (Earth-616)
# 1621    571077                                  Aiden (Earth-616)
# 1622    571073                      Cullen Bloodstone (Earth-616)
# 1623    570029                          Rebecca Ryker (Earth-616)
# ...

# %%
m1[m1['FIRST APPEARANCE']=='Jan-13'] #This now consists of the required list of youngest characters in Marvel.
# Out:
#        page_id                                               name  \
# 707     563846                               Eva Bell (Earth-616)
# 764     563845                       Christopher Muse (Earth-616)
# 1364    607100                          Emily Preston (Earth-616)
# 1365    563804                        Iara Dos Santos (Earth-616)
# 1563    573762                             H.E.L.E.N. (Earth-616)
# 1844    659271                               Jet Zola (Earth-616)
# 2032    695433                            Scott Adsit (Earth-616)
# 2146    669694    Charles Xavier (Legion Personality) (Earth-616)
# 2282    669682  Tyrannix the Abominoid (Legion Personality) (E...
# 2546    566881                  Necromancer (Michael) (Earth-616)
# 2725    657706                               Ian Zola (Earth-616)
# 2726    580217                           Karasu-Tengu (Earth-616)
# 2906    578694                            Luca Aldine (Earth-616)
# ...

# %%
m1[m1['FIRST APPEARANCE']=='Jan-13']['name']
# Out:
# 707                                   Eva Bell (Earth-616)
# 764                           Christopher Muse (Earth-616)
# 1364                             Emily Preston (Earth-616)
# 1365                           Iara Dos Santos (Earth-616)
# 1563                                H.E.L.E.N. (Earth-616)
# 1844                                  Jet Zola (Earth-616)
# 2032                               Scott Adsit (Earth-616)
# 2146       Charles Xavier (Legion Personality) (Earth-616)
# 2282     Tyrannix the Abominoid (Legion Personality) (E...
# 2546                     Necromancer (Michael) (Earth-616)
# 2725                                  Ian Zola (Earth-616)
# 2726                              Karasu-Tengu (Earth-616)
# 2906                               Luca Aldine (Earth-616)
# 2908                                    Mudbug (Earth-616)
# 3635                              Agent Gorman (Earth-616)
# 3638                        Gorr (God Butcher) (Earth-616)
# ...

# %%
dc.sort_values(by ='YEAR', ascending=False)  #similarly, for DC.
# Out:
#       page_id                                    name  \
# 5539    85254         Springheeled Jack (Prime Earth)
# 5540   309868                    Napalm (Prime Earth)
# 6541   306472             Matteo Bischoff (New Earth)
# 4324   379078  Ragnar (Green Lantern Animated Series)
# 3106   308460              Rachel Niamo (Prime Earth)
# 2843   291562          Kimberly Rebecki (Prime Earth)
# 3436   260130                      Bedbug (New Earth)
# 4331   199052                  Galenthias (New Earth)
# 4339   239915               Nina Mazursky (New Earth)
# 4338   285908             Miranda Shrieve (New Earth)
# 4337   214704                       Mimic (New Earth)
# 4336   245723                Martin Mayne (New Earth)
# 4335   302540              Jennifer Blitz (New Earth)
# 4334   272307                   Jay Young (New Earth)
# 4333   266573             Janosz Valentin (New Earth)
# 4332   295258                  Inertia II (New Earth)
# ...

# %%
dc.sort_values(by ='YEAR', ascending=False)['name'].head(1)  #Since there is only one character with the lastest year,2013.
# Out:
# 5539    Springheeled Jack (Prime Earth)
# Name: name, dtype: object

# %% [raw]
# 3. Are all bad characters dead?

# %%
marvel[marvel['ALIVE']=='Living Characters'][marvel['ALIGN']=='Bad Characters'].shape
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# (4791, 13)

# %%
dc[dc['ALIVE']=='Living Characters'][dc['ALIGN']=='Bad Characters'].shape
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# (2091, 13)

# %% [raw]
# Therefore, there are 4791 living bad characters in Marvel and 2091 of the same in DC, i.e., there is a total of 6882 living bad characters in Marvel and DC combined.

# %% [raw]
# 4. Characters with secret identities and their alias':

# %%
marvel[marvel['ID']=='Secret Identity'].shape #To find nunber of characters with secret identities
# Out:
# (6275, 13)

# %%
host=list()
name_list = marvel[marvel['ID']=='Secret Identity']['name'].tolist()
for i in range(6275):
    sppos = name_list[i].find(' ',0)
    value = name_list[i][0:sppos]
    host.append(value)
alias=pd.Series(name_list)
alias
# Out:
# 0                               Spider-Man (Peter Parker)
# 1                                Robert Drake (Earth-616)
# 2                              Piotr Rasputin (Earth-616)
# 3                                 Kurt Wagner (Earth-616)
# 4                                      Vision (Earth-616)
# 5                             Katherine Pryde (Earth-616)
# 6                          Rogue (Anna Marie) (Earth-616)
# 7                          Elizabeth Braddock (Earth-616)
# 8                             Eugene Thompson (Earth-616)
# 9                              Samuel Guthrie (Earth-616)
# 10                      James Buchanan Barnes (Earth-616)
# 11                                Remy LeBeau (Earth-616)
# 12                                Daniel Rand (Earth-616)
# 13                              Richard Jones (Earth-616)
# 14                            Patricia Walker (Earth-616)
# 15                              Otto Octavius (Earth-616)
# ...

# %%
dc[dc['ID']=='Secret Identity'].shape
# Out:
# (2408, 13)

# %%
host1=list()
name_list = dc[dc['ID']=='Secret Identity']['name'].tolist()
for i in range(2408):
    sppos = name_list[i].find(' ',0)
    value = name_list[i][0:sppos]
    host1.append(value)
alias1=pd.Series(name_list)
alias1
# Out:
# 0                Batman (Bruce Wayne)
# 1               Superman (Clark Kent)
# 2          Green Lantern (Hal Jordan)
# 3         Richard Grayson (New Earth)
# 4           Timothy Drake (New Earth)
# 5                 Flash (Barry Allen)
# 6                          GenderTest
# 7              Alan Scott (New Earth)
# 8          Barbara Gordon (New Earth)
# 9             Carter Hall (New Earth)
# 10            Kyle Rayner (New Earth)
# 11             Roy Harper (New Earth)
# 12             Kara Zor-L (Earth-Two)
# 13              Ted Grant (New Earth)
# 14                 Kon-El (New Earth)
# 15                  Joker (New Earth)
# 16              Rex Mason (New Earth)
# 17                  Aztar (New Earth)
# 18          Theodore Kord (New Earth)
# 19            Kent Nelson (New Earth)
# 20            Rachel Roth (New Earth)
# 21      Helena Bertinelli (New Earth)
# 22           Wesley Dodds (New Earth)
# 23         Nathaniel Adam (New Earth)
# 24         Ronald Raymond (New Earth)
# ...

# %% [raw]
# 5. FInding the statistics for physical attributes including eye colour and hair colour of the charatcers:

# %%
marvel['EYE'].describe()
# Out:
# count          6609
# unique           24
# top       Blue Eyes
# freq           1962
# Name: EYE, dtype: object

# %%
marvel['HAIR'].describe()
# Out:
# count          12112
# unique            25
# top       Black Hair
# freq            3755
# Name: HAIR, dtype: object

# %%
dc['EYE'].describe()
# Out:
# count          3268
# unique           17
# top       Blue Eyes
# freq           1102
# Name: EYE, dtype: object

# %%
dc['HAIR'].describe()
# Out:
# count           4622
# unique            17
# top       Black Hair
# freq            1574
# Name: HAIR, dtype: object

# %% [raw]
# Therefore, we see that for both Marvel and DC, blue eyes and black hair is the most common attribute.

# %% [raw]
# 6. Plotting overall gender evolvement in Marvel and DC according to the year:

# %%
dc.groupby('YEAR')['SEX'].value_counts().unstack().plot(figsize = (16,6))
plt.title('DC - Gender Evolvement')

marvel.groupby('Year')['SEX'].value_counts().unstack().plot(figsize = (16,6))
plt.title('Marvel - Gender Evolvement')
# Out:
# Text(0.5, 1.0, 'Marvel - Gender Evolvement')

# %% [raw]
# 7. Plotting the appearances of the characters:

# %%
plt.bar(dc['YEAR'].tolist(),dc['APPEARANCES'].tolist(),align = 'center')
# Out:
# <BarContainer object of 6896 artists>

# %%
plt.bar(marvel['Year'].tolist(),marvel['APPEARANCES'].tolist(),align = 'center')
# Out:
# <BarContainer object of 16376 artists>
