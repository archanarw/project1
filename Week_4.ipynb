# %%
x=c(1,2,3,4)
length(x)
# Out:
# [1] 4

# %%
y=c(6,7,9,8)
x+y
# Out:
# [1]  7  9 12 12

# %%
ls()
# Out:
# [1] "x" "y"

# %%
rm(list=ls())

# %%
ls()
# Out:
# character(0)

# %%
x=matrix(data=c(1,2,3,4),ncol=2)
x
# Out:
#      [,1] [,2]
# [1,] 1    3
# [2,] 2    4

# %%
matrix(c(1,2,3,4),2,byrow=TRUE)
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4

# %%
x=rnorm(50)
y=x+rnorm(50,mean=10)
cor(x,y)
# Out:
# [1] 0.7563304

# %%
plot(x,y,xlab="X-axis",ylab="Y-axis",main="Graph")

# %%
jpeg("Figure.pdf")
plot(x,y,col="green")
dev.off()
# Out:
# png
#   2

# %%
x=seq(-pi,pi,length=10)
x
# Out:
#  [1] -3.1415927 -2.4434610 -1.7453293 -1.0471976 -0.3490659  0.3490659
#  [7]  1.0471976  1.7453293  2.4434610  3.1415927

# %%
y=x
f=outer(x,y,function (x,y)cos(y)/(1+x^2))
contour(x,y,f)
image (x,y,f)
persp(x,y,f,theta=30,phi=50)

# %%
A=matrix (1:16,4,4)
A[2,3]
# Out:
# [1] 10

# %%
Auto=read.csv("Auto.csv")
College=read.csv("College.csv")
dim(College)
# Out:
# [1] 777  19

# %%
dim(Auto)
# Out:
# [1] 397   9

# %%
Auto=na.omit(Auto)
dim(Auto)
# Out:
# [1] 397   9

# %%
names(Auto)
# Out:
# [1] "mpg"          "cylinders"    "displacement" "horsepower"   "weight"
# [6] "acceleration" "year"         "origin"       "name"

# %%
attach(Auto)
plot(cylinders,mpg)

# %%
summary(Auto)
# Out:
#       mpg          cylinders      displacement     horsepower      weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   150    : 22   Min.   :1613
#  1st Qu.:17.50   1st Qu.:4.000   1st Qu.:104.0   90     : 20   1st Qu.:2223
#  Median :23.00   Median :4.000   Median :146.0   88     : 19   Median :2800
#  Mean   :23.52   Mean   :5.458   Mean   :193.5   110    : 18   Mean   :2970
#  3rd Qu.:29.00   3rd Qu.:8.000   3rd Qu.:262.0   100    : 17   3rd Qu.:3609
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   75     : 14   Max.   :5140
#                                                  (Other):287
#   acceleration        year           origin                  name
#  Min.   : 8.00   Min.   :70.00   Min.   :1.000   ford pinto    :  6
#  1st Qu.:13.80   1st Qu.:73.00   1st Qu.:1.000   amc matador   :  5
#  Median :15.50   Median :76.00   Median :1.000   ford maverick :  5
#  Mean   :15.56   Mean   :75.99   Mean   :1.574   toyota corolla:  5
# ...

# %%
summary(cylinders)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   3.000   4.000   4.000   5.458   8.000   8.000

# %%
plot(cylinders,mpg)
cylinders=as.factor(cylinders)
plot(cylinders,mpg)
plot(cylinders,mpg,col="red",varwidth=T)

# %%
hist(mpg ,col=4,breaks =15)

# %%
names(College)
# Out:
#  [1] "X"           "Private"     "Apps"        "Accept"      "Enroll"
#  [6] "Top10perc"   "Top25perc"   "F.Undergrad" "P.Undergrad" "Outstate"
# [11] "Room.Board"  "Books"       "Personal"    "PhD"         "Terminal"
# [16] "S.F.Ratio"   "perc.alumni" "Expend"      "Grad.Rate"

# %%
College=College[,-1]
College[1:4,]
# Out:
#   Private Apps Accept Enroll Top10perc Top25perc F.Undergrad P.Undergrad
# 1 Yes     1660 1232   721    23        52        2885         537
# 2 Yes     2186 1924   512    16        29        2683        1227
# 3 Yes     1428 1097   336    22        50        1036          99
# 4 Yes      417  349   137    60        89         510          63
#   Outstate Room.Board Books Personal PhD Terminal S.F.Ratio perc.alumni Expend
# 1  7440    3300       450   2200     70  78       18.1      12           7041
# 2 12280    6450       750   1500     29  30       12.2      16          10527
# 3 11250    3750       400   1165     53  66       12.9      30           8735
# 4 12960    5450       450    875     92  97        7.7      37          19016
#   Grad.Rate
# 1 60
# 2 56
# 3 54
# 4 59

# %%
range(mpg)
# Out:
# [1]  9.0 46.6

# %%
sd(mpg)
# Out:
# [1] 7.825804

# %%
mean(mpg)
# Out:
# [1] 23.51587

# %%
Auto=Auto[10:85,]
dim(Auto)
# Out:
# [1] 76  9

# %%
Boston=read.csv("Boston.csv")

# %%
dim(Boston)
# Out:
# [1] 506  15

# %%
pairs(Boston)
# Out:
# Error in replayPlot(obj): invalid graphics state
# Traceback:
# Error in replayPlot(obj): invalid graphics state
# Traceback:
# Error in replayPlot(obj): invalid graphics state
# Traceback:

# %%
names(Boston)
# Out:
#  [1] "X"       "crim"    "zn"      "indus"   "chas"    "nox"     "rm"
#  [8] "age"     "dis"     "rad"     "tax"     "ptratio" "black"   "lstat"
# [15] "medv"

# %%
??Boston

# %%
attach(Boston)
lm.fit=lm(medv~lstat)

# %%
summary(lm.fit)
lm.fit
# Out:
# Call:
# lm(formula = medv ~ lstat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.168  -3.990  -1.318   2.034  24.500
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 34.55384    0.56263   61.41   <2e-16 ***
# lstat       -0.95005    0.03873  -24.53   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.216 on 504 degrees of freedom
# Multiple R-squared:  0.5441,	Adjusted R-squared:  0.5432
# F-statistic: 601.6 on 1 and 504 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = medv ~ lstat)
#
# Coefficients:
# (Intercept)        lstat
#       34.55        -0.95

# %%
names(lm.fit)
# Out:
#  [1] "coefficients"  "residuals"     "effects"       "rank"
#  [5] "fitted.values" "assign"        "qr"            "df.residual"
#  [9] "xlevels"       "call"          "terms"         "model"

# %%
coef(lm.fit)
# Out:
# (Intercept)       lstat
#  34.5538409  -0.9500494

# %%
confint(lm.fit)
# Out:
#             2.5 %     97.5 %
# (Intercept) 33.448457 35.6592247
# lstat       -1.026148 -0.8739505

# %%
predict (lm.fit ,data.frame(lstat=c(2,4,6)), interval="confidence")
# Out:
#   fit      lwr      upr
# 1 32.65374 31.67807 33.62942
# 2 30.75364 29.90022 31.60707
# 3 28.85354 28.11121 29.59588

# %%
plot(lstat ,medv)
abline(lm.fit)

# %%
abline(0,1)
# Out:
# Error in int_abline(a = a, b = b, h = h, v = v, untf = untf, ...): plot.new has not been called yet
# Traceback:
#
# 1. abline(0, 1)
# 2. int_abline(a = a, b = b, h = h, v = v, untf = untf, ...)

# %%
plot(lstat ,medv ,pch='*')

# %%
par(mfrow=c(2,2))
plot(lm.fit)
# Out:
# Error in replayPlot(obj): invalid graphics state
# Traceback:
# Error in replayPlot(obj): invalid graphics state
# Traceback:
# Error in replayPlot(obj): invalid graphics state
# Traceback:

# %%
plot(lm.fit)
# Out:
# Error in plot.xy(xy, type, ...): invalid graphics state
# Traceback:
#
# 1. plot(lm.fit)
# 2. plot.lm(lm.fit)
# 3. plot(yhn0, sqrtabsr, xlab = l.fit, ylab = yl, main = main, ylim = ylim,
#  .     type = "n", ...)
# 4. plot.default(yhn0, sqrtabsr, xlab = l.fit, ylab = yl, main = main,
#  .     ylim = ylim, type = "n", ...)
# 5. plot.xy(xy, type, ...)

# %%
plot(predict(lm.fit),residuals(lm.fit))

# %%
rstudent(lm.fit)
# Out:
#             1             2             3             4             5
# -0.9386390949 -0.6875112380  0.6406663475  0.2642361813  1.0818817156
#             6             7             8             9            10
# -0.1456097331  0.0249804069  1.7343787934  1.6846408653  0.0952794075
#            11            12            13            14            15
# -0.0201873356 -0.4902737911  0.3333513061 -1.0160056474 -1.0641461877
#            16            17            18            19            20
# -1.0644855698 -0.8381704998 -0.5015686617 -0.5226539229 -0.9077061713
#            21            22            23            24            25
# -0.1584949730 -0.2919761614 -0.2526054641 -0.1879228730 -0.5582575125
#            26            27            28            29            30
# -0.8000801401 -0.6250972168 -0.5372348717 -0.6426943959 -0.3495186205
#            31            32            33            34            35
# ...

# %%
plot(hatvalues(lm.fit))

# %%
which.max(hatvalues(lm.fit))
# Out:
# 375
# 375

# %%
lm.fit=lm(medv~lstat+age,data=Boston)
par(mfrow=c(2,2))
plot(lm.fit)
# Out:
# Error in replayPlot(obj): invalid graphics state
# Traceback:
# Error in replayPlot(obj): invalid graphics state
# Traceback:
# Error in replayPlot(obj): invalid graphics state
# Traceback:

# %%
summary (lm.fit)
# Out:
# Call:
# lm(formula = medv ~ ., data = Boston)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.8948  -2.7585  -0.4663   1.7963  26.0911
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  36.461352   5.100994   7.148 3.21e-12 ***
# X            -0.002526   0.002080  -1.215 0.225046
# crim         -0.108762   0.032855  -3.310 0.001000 **
# zn            0.048031   0.013785   3.484 0.000538 ***
# indus         0.019932   0.061468   0.324 0.745871
# chas          2.705245   0.861298   3.141 0.001786 **
# nox         -17.541602   3.822390  -4.589 5.66e-06 ***
# rm            3.839225   0.418422   9.175  < 2e-16 ***
# age          -0.001938   0.013380  -0.145 0.884866
# dis          -1.493304   0.199892  -7.471 3.68e-13 ***
# rad           0.324925   0.068111   4.771 2.43e-06 ***
# tax          -0.011598   0.003807  -3.046 0.002443 **
# ptratio      -0.947985   0.130822  -7.246 1.67e-12 ***
# ...

# %%
lm.fit=lm(medv~.,data=Boston)
summary(lm.fit)
# Out:
# Call:
# lm(formula = medv ~ ., data = Boston)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.8948  -2.7585  -0.4663   1.7963  26.0911
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  36.461352   5.100994   7.148 3.21e-12 ***
# X            -0.002526   0.002080  -1.215 0.225046
# crim         -0.108762   0.032855  -3.310 0.001000 **
# zn            0.048031   0.013785   3.484 0.000538 ***
# indus         0.019932   0.061468   0.324 0.745871
# chas          2.705245   0.861298   3.141 0.001786 **
# nox         -17.541602   3.822390  -4.589 5.66e-06 ***
# rm            3.839225   0.418422   9.175  < 2e-16 ***
# age          -0.001938   0.013380  -0.145 0.884866
# dis          -1.493304   0.199892  -7.471 3.68e-13 ***
# rad           0.324925   0.068111   4.771 2.43e-06 ***
# tax          -0.011598   0.003807  -3.046 0.002443 **
# ptratio      -0.947985   0.130822  -7.246 1.67e-12 ***
# ...

# %%
plot(lm.fit)
# Out:
# Error in plot.xy(xy, type, ...): invalid graphics state
# Traceback:
#
# 1. plot(lm.fit)
# 2. plot.lm(lm.fit)
# 3. plot(yhn0, sqrtabsr, xlab = l.fit, ylab = yl, main = main, ylim = ylim,
#  .     type = "n", ...)
# 4. plot.default(yhn0, sqrtabsr, xlab = l.fit, ylab = yl, main = main,
#  .     ylim = ylim, type = "n", ...)
# 5. plot.xy(xy, type, ...)

# %%
summary(lm.fit)$sigma
# Out:
# [1] 4.743006

# %%
summary(lm.fit)$r.sq
# Out:
# [1] 0.7414198

# %%
vif(lm.fit)
# Out:
# Error in vif(lm.fit): could not find function "vif"
# Traceback:

# %%
lm.fit_new=lm(medv~.-age,data = Boston)
summary(lm.fit_new)
# Out:
# Call:
# lm(formula = medv ~ . - age, data = Boston)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.8593  -2.7788  -0.4885   1.7977  26.0250
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  36.522841   5.078247   7.192 2.39e-12 ***
# X            -0.002477   0.002050  -1.208 0.227466
# crim         -0.108764   0.032822  -3.314 0.000989 ***
# zn            0.048236   0.013698   3.521 0.000469 ***
# indus         0.019935   0.061407   0.325 0.745597
# chas          2.698637   0.859234   3.141 0.001787 **
# nox         -17.690669   3.677641  -4.810 2.01e-06 ***
# rm            3.826310   0.408408   9.369  < 2e-16 ***
# dis          -1.484659   0.190588  -7.790 4.01e-14 ***
# rad           0.325280   0.067999   4.784 2.28e-06 ***
# tax          -0.011628   0.003798  -3.062 0.002321 **
# ptratio      -0.949539   0.130252  -7.290 1.24e-12 ***
# black         0.009331   0.002677   3.486 0.000534 ***
# ...

# %%
lm.fit_new=update(lm.fit,~.-age)
summary(lm.fit_new)
# Out:
# Call:
# lm(formula = medv ~ X + crim + zn + indus + chas + nox + rm +
#     dis + rad + tax + ptratio + black + lstat, data = Boston)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.8593  -2.7788  -0.4885   1.7977  26.0250
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  36.522841   5.078247   7.192 2.39e-12 ***
# X            -0.002477   0.002050  -1.208 0.227466
# crim         -0.108764   0.032822  -3.314 0.000989 ***
# zn            0.048236   0.013698   3.521 0.000469 ***
# indus         0.019935   0.061407   0.325 0.745597
# chas          2.698637   0.859234   3.141 0.001787 **
# nox         -17.690669   3.677641  -4.810 2.01e-06 ***
# rm            3.826310   0.408408   9.369  < 2e-16 ***
# dis          -1.484659   0.190588  -7.790 4.01e-14 ***
# rad           0.325280   0.067999   4.784 2.28e-06 ***
# tax          -0.011628   0.003798  -3.062 0.002321 **
# ptratio      -0.949539   0.130252  -7.290 1.24e-12 ***
# ...

# %%
summary (lm(medv~lstat*age,data=Boston))
# Out:
# Call:
# lm(formula = medv ~ lstat * age, data = Boston)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.806  -4.045  -1.333   2.085  27.552
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 36.0885359  1.4698355  24.553  < 2e-16 ***
# lstat       -1.3921168  0.1674555  -8.313 8.78e-16 ***
# age         -0.0007209  0.0198792  -0.036   0.9711
# lstat:age    0.0041560  0.0018518   2.244   0.0252 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.149 on 502 degrees of freedom
# Multiple R-squared:  0.5557,	Adjusted R-squared:  0.5531
# F-statistic: 209.3 on 3 and 502 DF,  p-value: < 2.2e-16

# %%
summary(lm(medv~lstat+age+lstat:age,data=Boston))
# Out:
# Call:
# lm(formula = medv ~ lstat + age + lstat:age, data = Boston)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.806  -4.045  -1.333   2.085  27.552
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 36.0885359  1.4698355  24.553  < 2e-16 ***
# lstat       -1.3921168  0.1674555  -8.313 8.78e-16 ***
# age         -0.0007209  0.0198792  -0.036   0.9711
# lstat:age    0.0041560  0.0018518   2.244   0.0252 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.149 on 502 degrees of freedom
# Multiple R-squared:  0.5557,	Adjusted R-squared:  0.5531
# F-statistic: 209.3 on 3 and 502 DF,  p-value: < 2.2e-16

# %%
lm.fit1=lm(medv~lstat+I(lstat^2))
summary(lm.fit1)
# Out:
# Call:
# lm(formula = medv ~ lstat + I(lstat^2))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.2834  -3.8313  -0.5295   2.3095  25.4148
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 42.862007   0.872084   49.15   <2e-16 ***
# lstat       -2.332821   0.123803  -18.84   <2e-16 ***
# I(lstat^2)   0.043547   0.003745   11.63   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.524 on 503 degrees of freedom
# Multiple R-squared:  0.6407,	Adjusted R-squared:  0.6393
# F-statistic: 448.5 on 2 and 503 DF,  p-value: < 2.2e-16

# %%
lm.fit=lm(medv~lstat,data=Boston)
anova(lm.fit,lm.fit1)
# Out:
#   Res.Df RSS      Df Sum of Sq F        Pr(>F)
# 1 504    19472.38 NA       NA        NA           NA
# 2 503    15347.24  1 4125.138  135.1998 7.630116e-28

# %%
lm.fit2=lm(medv~lstat+poly(lstat,3))
anova(lm.fit,lm.fit2)
# Out:
#   Res.Df RSS      Df Sum of Sq F        Pr(>F)
# 1 504    19472.38 NA     NA          NA           NA
# 2 502    14615.48  2 4856.9    83.41032 5.295503e-32

# %%
Carseats=read.csv("Carseats.csv",header=TRUE)

# %%
names(Carseats)
# Out:
#  [1] "Sales"       "CompPrice"   "Income"      "Advertising" "Population"
#  [6] "Price"       "ShelveLoc"   "Age"         "Education"   "Urban"
# [11] "US"

# %%
lm.fit=lm(Sales~.+Income:Advertising+Price:Age,data=Carseats)
summary(lm.fit)
# Out:
# Call:
# lm(formula = Sales ~ . + Income:Advertising + Price:Age, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.9208 -0.7503  0.0177  0.6754  3.3413
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)         6.5755654  1.0087470   6.519 2.22e-10 ***
# CompPrice           0.0929371  0.0041183  22.567  < 2e-16 ***
# Income              0.0108940  0.0026044   4.183 3.57e-05 ***
# Advertising         0.0702462  0.0226091   3.107 0.002030 **
# Population          0.0001592  0.0003679   0.433 0.665330
# Price              -0.1008064  0.0074399 -13.549  < 2e-16 ***
# ShelveLocGood       4.8486762  0.1528378  31.724  < 2e-16 ***
# ShelveLocMedium     1.9532620  0.1257682  15.531  < 2e-16 ***
# Age                -0.0579466  0.0159506  -3.633 0.000318 ***
# Education          -0.0208525  0.0196131  -1.063 0.288361
# UrbanYes            0.1401597  0.1124019   1.247 0.213171
# ...

# %%
attach(Carseats)
contrasts(ShelveLoc)
# Out:
#        Good Medium
# Bad    0    0
# Good   1    0
# Medium 0    1
